# %% [markdown]
# <a href="https://colab.research.google.com/github/ayusingh-54/ANALYSIS/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/ben10_aliens.csv")

# %%
df
# Out:
#     alien_id   alien_name        species      home_planet  strength_level  \
# 0          1      Alien X      Indeedite  Andromeda Prime               7
# 1          2    AmpFibian  Particularite          Zantron               5
# 2          3   Armodrillo  Discussionite      Tierra Nova               5
# 3          4  Astrodactyl      Acrossite             Hala              10
# 4          5       Atomix        Eastite           Sirius              10
# ..       ...          ...            ...              ...             ...
# 69        70      Way Big        Formite      Tierra Nova               7
# 70        71     Whampire        Riskite           Zygara               9
# 71        72     Wildmutt      Chanceite  Epsilon Eridani               8
# 72        73     Wildvine     Withoutite          Solaris               9
# 73        74         XLR8     Withoutite       Beta Hydri               9
#
#     speed_level  intelligence
# 0             8             6
# ...

# %%
df.head()
# Out:
#    alien_id   alien_name        species      home_planet  strength_level  \
# 0         1      Alien X      Indeedite  Andromeda Prime               7
# 1         2    AmpFibian  Particularite          Zantron               5
# 2         3   Armodrillo  Discussionite      Tierra Nova               5
# 3         4  Astrodactyl      Acrossite             Hala              10
# 4         5       Atomix        Eastite           Sirius              10
#
#    speed_level  intelligence
# 0            8             6
# 1            8             5
# 2            4            10
# 3            7             8
# 4            5            10
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['alien_id'].plot(kind='hist', bins=20, title='alien_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('alien_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sns.countplot(x='intelligence', data=df)
# Out:
# <Axes: xlabel='intelligence', ylabel='count'>

# %% [markdown]
# ## categorical data

# %%
df['intelligence'].value_counts().plot(kind='pai')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4172f405c0f7> in <cell line: 0>()
# ----> 1 df['intelligence'].value_counts().plot(kind='pai')
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     958
#     959         if kind not in self._all_kinds:
# --> 960             raise ValueError(
#     961                 f"{kind} is not a valid plot kind "
#     962                 f"Valid plot kinds: {self._all_kinds}"
#
# ValueError: pai is not a valid plot kind Valid plot kinds: ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
df['intelligence'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), title='Distribution of Alien Intelligence Levels')
plt.show() # Add this to display the plot

# %% [markdown]
# ## numerical data

# %%
df
# Out:
#     alien_id   alien_name        species      home_planet  strength_level  \
# 0          1      Alien X      Indeedite  Andromeda Prime               7
# 1          2    AmpFibian  Particularite          Zantron               5
# 2          3   Armodrillo  Discussionite      Tierra Nova               5
# 3          4  Astrodactyl      Acrossite             Hala              10
# 4          5       Atomix        Eastite           Sirius              10
# ..       ...          ...            ...              ...             ...
# 69        70      Way Big        Formite      Tierra Nova               7
# 70        71     Whampire        Riskite           Zygara               9
# 71        72     Wildmutt      Chanceite  Epsilon Eridani               8
# 72        73     Wildvine     Withoutite          Solaris               9
# 73        74         XLR8     Withoutite       Beta Hydri               9
#
#     speed_level  intelligence
# 0             8             6
# ...

# %%
plt.hist(df['intelligence'])
# Out:
# (array([ 9.,  0., 16.,  0.,  8.,  0., 15.,  0., 11., 15.]),
#  array([ 5. ,  5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['intelligence'])
# Out:
# <ipython-input-15-32f186123c62>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['intelligence'])
# <Axes: xlabel='intelligence', ylabel='Density'>

# %%
sns.boxplot(df['intelligence'])
# Out:
# <Axes: ylabel='intelligence'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6dc1c4c1753e> in <cell line: 0>()
# ----> 1 sns.heatmap(df.corr(), annot=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
# Calculate the correlation matrix, only including numerical columns
correlation_matrix = df.corr(numeric_only=True)

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# #bivarient

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
flight = sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ##ScateredPlot

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip' , hue= 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip' , hue= 'smoker' , style= 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip' , hue= 'smoker' , style= 'sex' , size= 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# prompt: Distplot bi varient

sns.jointplot(data=tips, x='total_bill', y='tip')
sns.jointplot(data=tips, x='total_bill', y='tip' , kind= 'hex')
sns.jointplot(data=tips, x='total_bill', y='tip' , kind= 'reg')
sns.jointplot(data=tips, x='total_bill', y='tip' , kind= 'kde')
sns.jointplot(data=tips, x='total_bill', y='tip' , kind= 'kde' , fill=True)
